# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshat-Kushwaha104/SD_AKSHAT-0014/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = 3
p = 2

# %%
def test(n,p):
    return n**p

# %%
test(3,2)
# Out:
# 9

# %%
a = lambda n, p :n**p

# %%
a(3,5)
# Out:
# 243

# %%
add = lambda x,y,z,p : x+y+z+p

# %%
add(2,1,2,3)
# Out:
# 8

# %%
c_to_f = lambda c : (9/5)*c + 32

# %%
c_to_f(45)
# Out:
# 113.0

# %%
f_to_c = lambda f : (f-32)*5/9

# %%
f_to_c(45)
# Out:
# 7.222222222222222

# %%
finding_max = lambda x,y : x if x>y else y

# %%
finding_max(245,12)
# Out:
# 245

# %%
s = "skills"

# %%
find_len = lambda s : len(s)

# %%
find_len(s)
# Out:
# 6

# %%
finding_min =lambda x,y,z : x if x<y and x<z else y if y<x and y<z else z

# %%
finding_min(567,342,100)
# Out:
# 100

# %%
l = [2,3,4,5,6]

# %%
def sq(x):
  return x**2

# %%
list(map(sq,l))
# Out:
# [4, 9, 16, 25, 36]

# %%
list(map(lambda x : x**2 , l))
# Out:
# [4, 9, 16, 25, 36]

# %%
l1 = [1,2,3,4,5]
l2 = [6,7,8,9,10]

list(map(lambda x,y : x+y , l1,l2))
# Out:
# [7, 9, 11, 13, 15]

# %%
def add(x,y) :
  return x+y

# %%
list(map(add,l1,l2))
# Out:
# [7, 9, 11, 13, 15]

# %%
s = "skills"
list(map(lambda s : s.upper() , s))
# Out:
# ['S', 'K', 'I', 'L', 'L', 'S']

# %%
from functools import reduce

# %%
l = [1,2,3,4,5]

# %%
reduce(lambda x,y : x+y , l)
# Out:
# 15

# %%
reduce(lambda x,y : x+y , [])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1369/1781114009.py in <cell line: 0>()
# ----> 1 reduce(lambda x,y : x+y , [])
#
# TypeError: reduce() of empty iterable with no initial value

# %%
reduce(lambda x,y : x+y , [1])
# Out:
# 1

# %%
reduce(lambda x,y : x*y , l)
# Out:
# 120

# %%
l
# Out:
# [1, 2, 3, 4, 5]

# %%
reduce(lambda x,y : x if x>y else y , l)
# Out:
# 5

# %%
list(filter(lambda x : x%2 == 0 , l))
# Out:
# [2, 4]

# %%
list(filter(lambda x : x%2 != 0 , l))
# Out:
# [1, 3, 5]
